# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import time
import os

from nbodysim import NBodySim

# %%
path = 'figs'
os.makedirs(path,exist_ok=True)

# %% [markdown]
# # Euler

# %%
METHOD = 'euler'

# %% [markdown]
# ### Circular/120 Degree

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.zeros(shape=(3,3))
for i in range(3):
    phi = i*2*np.pi/3
    pos_init[i][0] = np.cos(phi)
    pos_init[i][1] = np.sin(phi)

acc_init = np.zeros(shape=(3,3))
for i in range(3):
    for j in range(i+1,3):
        r_diff = pos_init[j]-pos_init[i]
        r_norm = np.linalg.norm(r_diff)
        acc_init[i] += G*M[j]*r_diff/r_norm**3
        acc_init[j] -= G*M[i]*r_diff/r_norm**3

vel_init = np.zeros(shape=(3,3))
vel_abs = np.sqrt(-acc_init[0][0])
for i in range(3):
    phi = i*2*np.pi/3
    vel_init[i][0] = -vel_abs*np.sin(phi)
    vel_init[i][1] = vel_abs*np.cos(phi)

# %%
euler_120_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
euler_120_1.run(T,dt,method=METHOD)
euler_120_1.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{euler_120_1.method}.png')
euler_120_1.plot(LIM=None,savepath=SAVEPATH)

# %%
euler_120_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
euler_120_2.run(T,dt,method=METHOD)
euler_120_2.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{euler_120_2.method}.png')
euler_120_2.plot(LIM=None,savepath=SAVEPATH)

# %%
euler_120_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
euler_120_3.run(T,dt,method=METHOD)
euler_120_3.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{euler_120_3.method}.png')
euler_120_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# ### Infinity/8 Orbit

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.array([[0.9700436,-0.24308753,0],
                     [-0.9700436,0.24308753,0],
                     [0,0,0]])

vel_init = np.array([[0.466203685,0.43236573,0],
                     [0.466203685,0.43236573,0],
                     [-2*0.466203685,-2*0.43236573,0]])

# %%
euler_8_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
euler_8_1.run(T,dt,METHOD)
euler_8_1.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{euler_8_1.method}.png')
euler_8_1.plot(LIM=None,savepath=SAVEPATH)

# %%
euler_8_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
euler_8_2.run(T,dt,METHOD)
euler_8_2.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{euler_8_2.method}.png')
euler_8_2.plot(LIM=None,savepath=SAVEPATH)

# %%
euler_8_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
euler_8_3.run(T,dt,METHOD)
euler_8_3.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{euler_8_3.method}.png')
euler_8_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# # Leapfrog

# %%
METHOD = 'leapfrog'

# %% [markdown]
# ### Circular/120 Degree

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.zeros(shape=(3,3))
for i in range(3):
    phi = i*2*np.pi/3
    pos_init[i][0] = np.cos(phi)
    pos_init[i][1] = np.sin(phi)

acc_init = np.zeros(shape=(3,3))
for i in range(3):
    for j in range(i+1,3):
        r_diff = pos_init[j]-pos_init[i]
        r_norm = np.linalg.norm(r_diff)
        acc_init[i] += G*M[j]*r_diff/r_norm**3
        acc_init[j] -= G*M[i]*r_diff/r_norm**3

vel_init = np.zeros(shape=(3,3))
vel_abs = np.sqrt(-acc_init[0][0])
for i in range(3):
    phi = i*2*np.pi/3
    vel_init[i][0] = -vel_abs*np.sin(phi)
    vel_init[i][1] = vel_abs*np.cos(phi)

# %%
lf_120_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
lf_120_1.run(T,dt,method=METHOD)
lf_120_1.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{lf_120_1.method}.png')
lf_120_1.plot(LIM=None,savepath=SAVEPATH)

# %%
lf_120_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
lf_120_2.run(T,dt,method=METHOD)
lf_120_2.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{lf_120_2.method}.png')
lf_120_2.plot(LIM=None,savepath=SAVEPATH)

# %%
lf_120_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
lf_120_3.run(T,dt,method=METHOD)
lf_120_3.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{lf_120_3.method}.png')
lf_120_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# ### Infinity/8 Orbit

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.array([[0.9700436,-0.24308753,0],
                     [-0.9700436,0.24308753,0],
                     [0,0,0]])

vel_init = np.array([[0.466203685,0.43236573,0],
                     [0.466203685,0.43236573,0],
                     [-2*0.466203685,-2*0.43236573,0]])

# %%
lf_8_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
lf_8_1.run(T,dt,METHOD)
lf_8_1.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{lf_8_1.method}.png')
lf_8_1.plot(LIM=None,savepath=SAVEPATH)

# %%
lf_8_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
lf_8_2.run(T,dt,METHOD)
lf_8_2.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{lf_8_2.method}.png')
lf_8_2.plot(LIM=None,savepath=SAVEPATH)

# %%
lf_8_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
lf_8_3.run(T,dt,METHOD)
lf_8_3.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{lf_8_3.method}.png')
lf_8_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# # Hermite

# %%
METHOD = 'hermite'

# %% [markdown]
# ### Circular/120 Degree

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.zeros(shape=(3,3))
for i in range(3):
    phi = i*2*np.pi/3
    pos_init[i][0] = np.cos(phi)
    pos_init[i][1] = np.sin(phi)

acc_init = np.zeros(shape=(3,3))
for i in range(3):
    for j in range(i+1,3):
        r_diff = pos_init[j]-pos_init[i]
        r_norm = np.linalg.norm(r_diff)
        acc_init[i] += G*M[j]*r_diff/r_norm**3
        acc_init[j] -= G*M[i]*r_diff/r_norm**3

vel_init = np.zeros(shape=(3,3))
vel_abs = np.sqrt(-acc_init[0][0])
for i in range(3):
    phi = i*2*np.pi/3
    vel_init[i][0] = -vel_abs*np.sin(phi)
    vel_init[i][1] = vel_abs*np.cos(phi)

# %%
hermite_120_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
hermite_120_1.run(T,dt,method=METHOD)
hermite_120_1.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{hermite_120_1.method}.png')
hermite_120_1.plot(LIM=None,savepath=SAVEPATH)

# %%
hermite_120_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
hermite_120_2.run(T,dt,method=METHOD)
hermite_120_2.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{hermite_120_2.method}.png')
hermite_120_2.plot(LIM=None,savepath=SAVEPATH)

# %%
hermite_120_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
hermite_120_3.run(T,dt,method=METHOD)
hermite_120_3.com_convert()

SAVEPATH = os.path.join(path,f'120deg_{dt}_{hermite_120_3.method}.png')
hermite_120_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# ### Inifity/8 Orbit

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.array([[0.9700436,-0.24308753,0],
                     [-0.9700436,0.24308753,0],
                     [0,0,0]])

vel_init = np.array([[0.466203685,0.43236573,0],
                     [0.466203685,0.43236573,0],
                     [-2*0.466203685,-2*0.43236573,0]])

# %%
hermite_8_1 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.01
hermite_8_1.run(T,dt,METHOD)
hermite_8_1.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{hermite_8_1.method}.png')
hermite_8_1.plot(LIM=None,savepath=SAVEPATH)

# %%
hermite_8_2 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
hermite_8_2.run(T,dt,METHOD)
hermite_8_2.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{hermite_8_2.method}.png')
hermite_8_2.plot(LIM=None,savepath=SAVEPATH)

# %%
hermite_8_3 = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.0001
hermite_8_3.run(T,dt,METHOD)
hermite_8_3.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{hermite_8_3.method}.png')
hermite_8_3.plot(LIM=None,savepath=SAVEPATH)

# %% [markdown]
# # Results

# %%
sims = [euler_120_1,euler_120_2,euler_120_3,
        euler_8_1,euler_8_2,euler_8_3,
        lf_120_1,lf_120_2,lf_120_3,
        lf_8_1,lf_8_2,lf_8_3,
        hermite_120_1,hermite_120_2,hermite_120_3,
        hermite_8_1,hermite_8_2,hermite_8_3]

orbits = []
methods = []
dts = []
running_times = []
energy_diffs = []
i = 0
for sim in sims:
    orbits.append('120deg' if i < 3 else '8')
    methods.append(sim.method)
    dts.append(sim.dt)
    running_times.append(sim.running_time)
    energy_diffs.append(sim.energy_diff())
    i += 1
    if i == 6:
        i = 0

results = pd.DataFrame([orbits,methods,dts,running_times,energy_diffs],index=['Orbit','Method','Timestep','Running Time','Energy Difference']).T
results.sort_values(by=['Orbit','Method'])
# Out:
#      Orbit    Method Timestep Running Time Energy Difference
# 0   120deg     euler     0.01     0.074835         -0.000022
# 1   120deg     euler    0.001     0.549933              -0.0
# 2   120deg     euler   0.0001     5.121891              -0.0
# 12  120deg   hermite     0.01     0.146611               0.0
# 13  120deg   hermite    0.001     1.238053               0.0
# 14  120deg   hermite   0.0001    11.619516              -0.0
# 6   120deg  leapfrog     0.01     0.068313              -0.0
# 7   120deg  leapfrog    0.001     0.597659              -0.0
# 8   120deg  leapfrog   0.0001     5.559144               0.0
# 3        8     euler     0.01     0.064108          0.000196
# 4        8     euler    0.001     0.545359          0.000021
# 5        8     euler   0.0001     4.861346          0.000002
# 15       8   hermite     0.01     0.127391               0.0
# 16       8   hermite    0.001     1.218999               0.0
# ...

# %% [markdown]
# # Integrator Difference Plot

# %%
sims = [euler_120_1,lf_120_1,hermite_120_1]

plt.figure(figsize=(10.5,7))
for i,sim in enumerate(sims):
    pos = sim.POS_COM
    E = sim.E
    plt.subplot(2,3,i+1)
    for j in range(3):
        plt.plot(pos[:,j,0],pos[:,j,1],zorder=1,color=f'C{j}')
        plt.scatter(pos[0,j,0],pos[0,j,1],zorder=2,color=f'C{j}')
    plt.title(f'{sim.method}\nRuntime = {sim.running_time:.2f} s')
    plt.xlabel('X (COM)')
    plt.ylabel('Y (COM)')

    plt.subplot(2,3,i+4)
    plt.plot((E-E[0])/E[0],label=rf'$\Delta E_{{rel}}$ = {E[-1]-E[0]:.2e}')
    plt.xlabel('T')
    plt.ylabel(r'$\Delta E_{rel}$')
    plt.title(rf'$\Delta E_{{rel}}$ = {E[-1]-E[0]:.2e}')
    # plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('./figs/circle_plot.png')
plt.show()

# %%
sims = [euler_8_1,lf_8_1,hermite_8_1]

plt.figure(figsize=(10.5,7))
for i,sim in enumerate(sims):
    pos = sim.POS_COM
    E = sim.E
    plt.subplot(2,3,i+1)
    for j in range(3):
        plt.plot(pos[:,j,0],pos[:,j,1],zorder=1,color=f'C{j}')
        plt.scatter(pos[0,j,0],pos[0,j,1],zorder=2,color=f'C{j}')
    plt.title(f'{sim.method}\nRuntime = {sim.running_time:.2f} s')
    plt.xlabel('X (COM)')
    plt.ylabel('Y (COM)')

    plt.subplot(2,3,i+4)
    plt.plot((E-E[0])/E[0],label=rf'$\Delta E_{{rel}}$ = {E[-1]-E[0]:.2e}')
    plt.xlabel('T')
    plt.ylabel(r'$\Delta E_{rel}$')
    plt.title(rf'$\Delta E_{{rel}}$ = {E[-1]-E[0]:.2e}')
    # plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('./figs/8_plot.png')
plt.show()

# %% [markdown]
# # Animation

# %% [markdown]
# ### Infinity Orbit

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.array([[0.9700436,-0.24308753,0],
                     [-0.9700436,0.24308753,0],
                     [0,0,0]])
vel_init = np.array([[0.466203685,0.43236573,0],
                     [0.466203685,0.43236573,0],
                     [-2*0.466203685,-2*0.43236573,0]])
anim_sim = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)
T,dt = 10,0.01
anim_sim.run(T,dt,'hermite')
anim_sim.com_convert()
anim_sim.plot(LIM=1.5)

# %%
from matplotlib.animation import FuncAnimation

pos = anim_sim.POS_COM
frames = pos.shape[0]

fig = plt.figure(figsize=(5,5))
ax = plt.axes(xlim=(-1.5,1.5),
              ylim=(-1.5,1.5))

trails = []
bodies = []
for i in range(anim_sim.N):
    trail, = ax.plot([],[],color=f'C{i}')
    body, = ax.plot([],[],color=f'C{i}',marker='o',label=f'Star mass: {M[i]:.2f}')
    trails.append(trail)
    bodies.append(body)

def update(frame):
    for i in range(anim_sim.N):
        trails[i].set_data(pos[max(0,frame-100):frame,i,0],pos[max(0,frame-100):frame,i,1])
        bodies[i].set_data([pos[frame,i,0]],[pos[frame,i,1]])
    return (*trails,*bodies)

anim = FuncAnimation(fig,update,frames=frames,interval=50,blit=True)
plt.legend(loc='upper right')
plt.tight_layout()
anim.save('8_dt001_hermite.mp4', fps=60)
plt.close()

# %% [markdown]
# ### Circular Orbit

# %%
M = np.array([1,1,1])
G = 1
pos_init = np.zeros(shape=(3,3))
for i in range(3):
    phi = i*2*np.pi/3
    pos_init[i][0] = np.cos(phi)
    pos_init[i][1] = np.sin(phi)

acc_init = np.zeros(shape=(3,3))
for i in range(3):
    for j in range(i+1,3):
        r_diff = pos_init[j]-pos_init[i]
        r_norm = np.linalg.norm(r_diff)
        acc_init[i] += G*M[j]*r_diff/r_norm**3
        acc_init[j] -= G*M[i]*r_diff/r_norm**3

vel_init = np.zeros(shape=(3,3))
vel_abs = np.sqrt(-acc_init[0][0])
for i in range(3):
    phi = i*2*np.pi/3
    vel_init[i][0] = -vel_abs*np.sin(phi)
    vel_init[i][1] = vel_abs*np.cos(phi)

anim_sim = NBodySim(N=3,DIM=3,POS=pos_init,VEL=vel_init,M=M,G=G)
T,dt = 10,0.01
anim_sim.run(T,dt,'hermite')
anim_sim.com_convert()
anim_sim.plot(LIM=1.5)

# %%
from matplotlib.animation import FuncAnimation

pos = anim_sim.POS_COM
frames = pos.shape[0]

fig = plt.figure(figsize=(5,5))
ax = plt.axes(xlim=(-1.5,1.5),
              ylim=(-1.5,1.5))

trails = []
bodies = []
for i in range(anim_sim.N):
    trail, = ax.plot([],[],color=f'C{i}')
    body, = ax.plot([],[],color=f'C{i}',marker='o',label=f'Star mass: {M[i]:.2f}')
    trails.append(trail)
    bodies.append(body)

def update(frame):
    for i in range(anim_sim.N):
        trails[i].set_data(pos[max(0,frame-100):frame,i,0],pos[max(0,frame-100):frame,i,1])
        bodies[i].set_data([pos[frame,i,0]],[pos[frame,i,1]])
    return (*trails,*bodies)

anim = FuncAnimation(fig,update,frames=frames,interval=50,blit=True)
plt.legend(loc='upper right')
plt.tight_layout()
anim.save('120_dt001_hermite.mp4', fps=60)
plt.close()

# %% [markdown]
# ### Random Parameters

# %%
np.random.seed(16)

N = 3
DIM = 3
G = 1

M = np.random.uniform(0,2,N)
M[0] = 6
pos_init = np.random.uniform(-1,1,size=(N,DIM))
vel_init = np.random.uniform(-1,1,size=(N,DIM))

# %%
random_hermite_001 = NBodySim(N=N,DIM=DIM,POS=pos_init,VEL=vel_init,M=M,G=G)

T,dt = 10,0.001
random_hermite_001.run(T,dt,'hermite')
random_hermite_001.com_convert()

SAVEPATH = os.path.join(path,f'8orbit_{dt}_{random_hermite_001.method}.png')
random_hermite_001.plot(LIM=None,savepath=None)

# %%
from matplotlib.animation import FuncAnimation

pos = random_hermite_001.POS_COM
frames = pos.shape[0]

fig = plt.figure(figsize=(5,5))
ax = plt.axes(xlim=(-1.5,1.5),
              ylim=(-1.5,1.5))
ax.set_xlabel('X (COM)')
ax.set_ylabel('Y (COM)')

trails = []
bodies = []
for i in range(anim_sim.N):
    trail, = ax.plot([],[],color=f'C{i}')
    body, = ax.plot([],[],color=f'C{i}',marker='o',label=f'Star mass: {M[i]:.2f}')
    trails.append(trail)
    bodies.append(body)

def update(frame):
    for i in range(anim_sim.N):
        trails[i].set_data(pos[max(0,frame-100):frame,i,0],pos[max(0,frame-100):frame,i,1])
        bodies[i].set_data([pos[frame,i,0]],[pos[frame,i,1]])
    return (*trails,*bodies)

anim = FuncAnimation(fig,update,frames=frames,interval=50,blit=True)
plt.legend(loc='upper right')
plt.tight_layout()
anim.save('random_seed16_001_hermite.mp4', fps=240)
plt.close()
